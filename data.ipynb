# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
ls = pd.read_csv('data/listings_05_13.csv')
lo = pd.read_csv('data/loans_05_13.csv')
# Out:
# /tmp/ipykernel_6270/627402110.py:1: DtypeWarning: Columns (6,16,25,26,27,37,38,512,530,534,537) have mixed types. Specify dtype option on import or set low_memory=False.
#   ls = pd.read_csv('data/listings_05_13.csv')

# %%
ls.head()
# Out:
#                 member_key  listing_number               credit_pull_date  \
# 0  0A8633658381202043D0226               2  2005-11-09 00:30:04.487000000
# 1  ED983364564478611B1273E               3  2005-11-09 12:01:07.900000000
# 2  D3123364665672102D89C63               4  2005-11-09 20:44:28.847000000
# 3  92263365124033374675E8D               6  2005-11-15 16:06:47.457000000
# 4  0A8633658381202043D0226               7  2005-11-09 00:30:04.487000000
#
#               listing_start_date               listing_end_date  \
# 0  2005-11-09 00:30:04.487000000  2005-11-15 18:24:05.717000000
# 1  2005-11-09 12:01:07.900000000  2005-11-16 12:04:10.367000000
# 2  2005-11-09 20:44:28.847000000  2005-11-10 18:21:20.910000000
# 3  2005-11-15 16:06:47.457000000  2005-11-18 16:10:28.637000000
# 4  2005-11-15 18:25:56.107000000  2005-11-17 15:05:28.210000000
#
#            listing_creation_date loan_origination_date  listing_status  \
# ...

# %%
for col in ls.columns:
    if "yield" in col:
        print(col)
# Out:
# lender_yield
# effective_yield

# %%
import requests
